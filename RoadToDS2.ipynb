# %% [markdown]
# <a href="https://colab.research.google.com/github/Vinamra11/RoadToDS/blob/main/RoadToDS2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Road To Data Science 2
#
# statistics
